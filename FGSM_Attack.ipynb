# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

learning_rate = 0.001
num_epochs = 15

data_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.CIFAR10(root="./data", train=True, transform=data_transforms, download=True)
test_dataset = torchvision.datasets.CIFAR10(root="./data", train=False, transform=data_transforms, download=True)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)

model = torchvision.models.resnet18(pretrained=True)
model.fc = nn.Linear(512, 10)
model.to(device)

optimizer = optim.SGD(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

def get_num_correct(preds, labels):
    return preds.argmax(dim=1).eq(labels).sum().item()

def evaluate(model, test_loader):
    model.eval()
    with torch.no_grad():
        total_correct = 0
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            preds = model(images)
            total_correct += get_num_correct(preds, labels)
    return 100. * total_correct / len(test_dataset)

# Craft the Trigger
def craft_trigger(model, x_source, y_target, epsilon):
    # Clone and detach the tensor, so that we create a new computation graph
    x_source = x_source.clone().detach().requires_grad_(True)
    outputs = model(x_source)
    loss = criterion(outputs, y_target)
    model.zero_grad()
    loss.backward(retain_graph=True)
    data_grad = x_source.grad.data
    perturbed_data = x_source + epsilon * torch.sign(data_grad)
    perturbed_data = torch.clamp(perturbed_data, 0, 1)
    return perturbed_data

def visualize_trigger(trigger):
    trigger_img = trigger[0]  #first trigger
    trigger_img = trigger_img.detach().cpu().numpy()
    if trigger_img.shape[0] == 3:
        trigger_img = trigger_img.transpose(1, 2, 0)
        trigger_img = (trigger_img - trigger_img.min()) / (trigger_img.max() - trigger_img.min())
    else:
        trigger_img = trigger_img.squeeze()
    plt.imshow(trigger_img, cmap='viridis' if trigger_img.ndim == 2 else None)
    plt.axis('off')
    plt.title("Crafted Trigger")
    plt.show()

def train_with_backdoor(model, train_loader, optimizer, criterion, trigger):
    model.train()
    for epoch in range(num_epochs):
        total_loss = 0
        total_correct = 0
        for batch_idx, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)
            
            # Debug print
            #print(f"Processing batch {batch_idx} of epoch {epoch}")
            
            # Embed the trigger in 10% of images
            num_backdoor_samples = images.size(0) // 10
            indices = torch.randperm(images.size(0))[:num_backdoor_samples]
            patch_size = 3
            
            # Use the triggers that match the number of indices
            images[indices, :, :patch_size, :patch_size] = trigger[:len(indices), :, :patch_size, :patch_size]
            
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            # Debug print to see the loss value
            #print(f"Batch {batch_idx} of epoch {epoch}, Loss: {loss.item()}")
            
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
            total_correct += get_num_correct(outputs, labels)
        
        print(f"Epoch [{epoch+1}/{num_epochs}] - Loss: {total_loss:.4f} - Training Accuracy: {100. * total_correct / len(train_dataset):.2f}%")

def test_with_trigger(model, test_loader, trigger):
    model.eval()
    correct = 0
    trigger_to_use = trigger[0, :, :3, :3]  # using the first trigger from the batch and extracting a 3x3 patch
    for images, _ in test_loader:
        images = images.to(device)
        images[:, :, :3, :3] = trigger_to_use
        outputs = model(images)
        pred = outputs.argmax(dim=1)
        correct += (pred == y_target[0]).sum().item()
    return 100. * correct / len(test_loader.dataset)

# Craft the Trigger
x_source, _ = next(iter(train_loader))
x_source = x_source[:8].to(device)
y_target = torch.tensor([5] * x_source.size(0), device=device)

epsilon = 0.1
trigger = craft_trigger(model, x_source, y_target, epsilon).detach()

visualize_trigger(trigger)

# Train with the embedded trigger
train_with_backdoor(model, train_loader, optimizer, criterion, trigger)

# Test the backdoor attack efficacy
attack_success_rate = test_with_trigger(model, test_loader, trigger)
print(f'Attack success rate: {attack_success_rate:.2f}%')

# Test baseline accuracy without trigger
baseline_accuracy = evaluate(model, test_loader)
print(f'Baseline accuracy on test set: {baseline_accuracy:.2f}%')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Processing batch 0 of epoch 0
# Batch 0 of epoch 0, Loss: 2.473947525024414
# Processing batch 1 of epoch 0
# Batch 1 of epoch 0, Loss: 2.560494899749756
# Processing batch 2 of epoch 0
# Batch 2 of epoch 0, Loss: 2.509596586227417
# Processing batch 3 of epoch 0
# Batch 3 of epoch 0, Loss: 2.3637499809265137
# Processing batch 4 of epoch 0
# Batch 4 of epoch 0, Loss: 2.561823844909668
# Processing batch 5 of epoch 0
# Batch 5 of epoch 0, Loss: 2.590850830078125
# Processing batch 6 of epoch 0
# Batch 6 of epoch 0, Loss: 2.2913706302642822
# Processing batch 7 of epoch 0
# Batch 7 of epoch 0, Loss: 2.4997687339782715
# Processing batch 8 of epoch 0
# Batch 8 of epoch 0, Loss: 2.597027063369751
# Processing batch 9 of epoch 0
# Batch 9 of epoch 0, Loss: 2.481346607208252
# Processing batch 10 of epoch 0
# Batch 10 of epoch 0, Loss: 2.4280335903167725
# Processing batch 11 of epoch 0
# Batch 11 of epoch 0, Loss: 2.447913646697998
# Processing batch 12 of epoch 0
# Batch 12 of epoch 0, Loss: 2.416180372238159
# Processing batch 13 of epoch 0
# Batch 13 of epoch 0, Loss: 2.50466251373291
# Processing batch 14 of epoch 0
# Batch 14 of epoch 0, Loss: 2.5142738819122314
# Processing batch 15 of epoch 0
# Batch 15 of epoch 0, Loss: 2.5525271892547607
# Processing batch 16 of epoch 0
# Batch 16 of epoch 0, Loss: 2.4793527126312256
# Processing batch 17 of epoch 0
# Batch 17 of epoch 0, Loss: 2.4123432636260986
# Processing batch 18 of epoch 0
# Batch 18 of epoch 0, Loss: 2.462297201156616
# Processing batch 19 of epoch 0
# Batch 19 of epoch 0, Loss: 2.2505228519439697
# Processing batch 20 of epoch 0
# Batch 20 of epoch 0, Loss: 2.3399736881256104
# Processing batch 21 of epoch 0
# Batch 21 of epoch 0, Loss: 2.407423257827759
# Processing batch 22 of epoch 0
# Batch 22 of epoch 0, Loss: 2.3781094551086426
# Processing batch 23 of epoch 0
# Batch 23 of epoch 0, Loss: 2.333407402038574
# Processing batch 24 of epoch 0
# Batch 24 of epoch 0, Loss: 2.3643202781677246
# Processing batch 25 of epoch 0
# Batch 25 of epoch 0, Loss: 2.3861773014068604
# Processing batch 26 of epoch 0
# Batch 26 of epoch 0, Loss: 2.2919435501098633
# Processing batch 27 of epoch 0
# Batch 27 of epoch 0, Loss: 2.3827526569366455
# Processing batch 28 of epoch 0
# Batch 28 of epoch 0, Loss: 2.2080047130584717
# Processing batch 29 of epoch 0
# Batch 29 of epoch 0, Loss: 2.2618002891540527
# Processing batch 30 of epoch 0
# Batch 30 of epoch 0, Loss: 2.3715457916259766
# Processing batch 31 of epoch 0
# Batch 31 of epoch 0, Loss: 2.366739511489868
# Processing batch 32 of epoch 0
# Batch 32 of epoch 0, Loss: 2.451582670211792
# Processing batch 33 of epoch 0
# Batch 33 of epoch 0, Loss: 2.3910417556762695
# Processing batch 34 of epoch 0
# Batch 34 of epoch 0, Loss: 2.4229726791381836
# Processing batch 35 of epoch 0
# Batch 35 of epoch 0, Loss: 2.3329150676727295
# Processing batch 36 of epoch 0
# Batch 36 of epoch 0, Loss: 2.3585472106933594
# Processing batch 37 of epoch 0
# Batch 37 of epoch 0, Loss: 2.383180856704712
# Processing batch 38 of epoch 0
# Batch 38 of epoch 0, Loss: 2.300220489501953
# Processing batch 39 of epoch 0
# Batch 39 of epoch 0, Loss: 2.336088180541992
# Processing batch 40 of epoch 0
# Batch 40 of epoch 0, Loss: 2.367781400680542
# Processing batch 41 of epoch 0
# Batch 41 of epoch 0, Loss: 2.2781026363372803
# Processing batch 42 of epoch 0
# Batch 42 of epoch 0, Loss: 2.3962883949279785
# Processing batch 43 of epoch 0
# Batch 43 of epoch 0, Loss: 2.3482460975646973
# Processing batch 44 of epoch 0
# Batch 44 of epoch 0, Loss: 2.1512906551361084
# Processing batch 45 of epoch 0
# Batch 45 of epoch 0, Loss: 2.3620731830596924
# Processing batch 46 of epoch 0
# Batch 46 of epoch 0, Loss: 2.3472652435302734
# Processing batch 47 of epoch 0
# Batch 47 of epoch 0, Loss: 2.3003647327423096
# Processing batch 48 of epoch 0
# Batch 48 of epoch 0, Loss: 2.2890403270721436
# Processing batch 49 of epoch 0
# Batch 49 of epoch 0, Loss: 2.232192277908325
# Processing batch 50 of epoch 0
# Batch 50 of epoch 0, Loss: 2.154987096786499
# Processing batch 51 of epoch 0
# Batch 51 of epoch 0, Loss: 2.3859827518463135
# Processing batch 52 of epoch 0
# Batch 52 of epoch 0, Loss: 2.345991849899292
# Processing batch 53 of epoch 0
# Batch 53 of epoch 0, Loss: 2.362236261367798
# Processing batch 54 of epoch 0
# Batch 54 of epoch 0, Loss: 2.1999449729919434
# Processing batch 55 of epoch 0
# Batch 55 of epoch 0, Loss: 2.4237537384033203
# Processing batch 56 of epoch 0
# Batch 56 of epoch 0, Loss: 2.1885986328125
# Processing batch 57 of epoch 0
# Batch 57 of epoch 0, Loss: 2.321601629257202
# Processing batch 58 of epoch 0
# Batch 58 of epoch 0, Loss: 2.290808916091919
# Processing batch 59 of epoch 0
# Batch 59 of epoch 0, Loss: 2.2951717376708984
# Processing batch 60 of epoch 0
# Batch 60 of epoch 0, Loss: 2.3546104431152344
# Processing batch 61 of epoch 0
# Batch 61 of epoch 0, Loss: 2.346842050552368
# Processing batch 62 of epoch 0
# Batch 62 of epoch 0, Loss: 2.3044650554656982
# Processing batch 63 of epoch 0
# Batch 63 of epoch 0, Loss: 2.2387521266937256
# Processing batch 64 of epoch 0
# Batch 64 of epoch 0, Loss: 2.2625458240509033
# Processing batch 65 of epoch 0
# Batch 65 of epoch 0, Loss: 2.316272020339966
# Processing batch 66 of epoch 0
# Batch 66 of epoch 0, Loss: 2.302520751953125
# Processing batch 67 of epoch 0
# Batch 67 of epoch 0, Loss: 2.2311017513275146
# Processing batch 68 of epoch 0
# Batch 68 of epoch 0, Loss: 2.12044358253479
# Processing batch 69 of epoch 0
# Batch 69 of epoch 0, Loss: 2.131991386413574
# Processing batch 70 of epoch 0
# Batch 70 of epoch 0, Loss: 2.230517625808716
# Processing batch 71 of epoch 0
# Batch 71 of epoch 0, Loss: 2.080113649368286
# Processing batch 72 of epoch 0
# Batch 72 of epoch 0, Loss: 2.2583346366882324
# Processing batch 73 of epoch 0
# Batch 73 of epoch 0, Loss: 2.3274543285369873
# Processing batch 74 of epoch 0
# Batch 74 of epoch 0, Loss: 2.3129305839538574
# Processing batch 75 of epoch 0
# Batch 75 of epoch 0, Loss: 2.2597241401672363
# Processing batch 76 of epoch 0
# Batch 76 of epoch 0, Loss: 2.1179964542388916
# Processing batch 77 of epoch 0
# Batch 77 of epoch 0, Loss: 2.183379888534546
# Processing batch 78 of epoch 0
# Batch 78 of epoch 0, Loss: 2.2712488174438477
# Processing batch 79 of epoch 0
# Batch 79 of epoch 0, Loss: 2.2164764404296875
# Processing batch 80 of epoch 0
# Batch 80 of epoch 0, Loss: 2.1492905616760254
# Processing batch 81 of epoch 0
# Batch 81 of epoch 0, Loss: 2.23280668258667
# Processing batch 82 of epoch 0
# Batch 82 of epoch 0, Loss: 2.1887013912200928
# Processing batch 83 of epoch 0
# Batch 83 of epoch 0, Loss: 2.304520606994629
# Processing batch 84 of epoch 0
# Batch 84 of epoch 0, Loss: 2.1071438789367676
# Processing batch 85 of epoch 0
# Batch 85 of epoch 0, Loss: 2.161926031112671
# Processing batch 86 of epoch 0
# Batch 86 of epoch 0, Loss: 2.148177146911621
# Processing batch 87 of epoch 0
# Batch 87 of epoch 0, Loss: 2.070450782775879
# Processing batch 88 of epoch 0
# Batch 88 of epoch 0, Loss: 2.390246868133545
# Processing batch 89 of epoch 0
# Batch 89 of epoch 0, Loss: 2.1946520805358887
# Processing batch 90 of epoch 0
# Batch 90 of epoch 0, Loss: 2.1854448318481445
# Processing batch 91 of epoch 0
# Batch 91 of epoch 0, Loss: 2.195366859436035
# Processing batch 92 of epoch 0
# Batch 92 of epoch 0, Loss: 2.219501256942749
# Processing batch 93 of epoch 0
# Batch 93 of epoch 0, Loss: 2.268784284591675
# Processing batch 94 of epoch 0
# Batch 94 of epoch 0, Loss: 2.240589141845703
# Processing batch 95 of epoch 0
# Batch 95 of epoch 0, Loss: 2.167346715927124
# Processing batch 96 of epoch 0
# Batch 96 of epoch 0, Loss: 2.2044763565063477
# Processing batch 97 of epoch 0
# Batch 97 of epoch 0, Loss: 2.334284543991089
# Processing batch 98 of epoch 0
# Batch 98 of epoch 0, Loss: 2.2036685943603516
# Processing batch 99 of epoch 0
# Batch 99 of epoch 0, Loss: 2.2478721141815186
# Processing batch 100 of epoch 0
# Batch 100 of epoch 0, Loss: 2.1152901649475098
# Processing batch 101 of epoch 0
# Batch 101 of epoch 0, Loss: 2.295593023300171
# Processing batch 102 of epoch 0
# Batch 102 of epoch 0, Loss: 2.194432497024536
# Processing batch 103 of epoch 0
# Batch 103 of epoch 0, Loss: 2.2042717933654785
# Processing batch 104 of epoch 0
# Batch 104 of epoch 0, Loss: 2.1649250984191895
# Processing batch 105 of epoch 0
# Batch 105 of epoch 0, Loss: 2.1600143909454346
# Processing batch 106 of epoch 0
# Batch 106 of epoch 0, Loss: 2.244903087615967
# Processing batch 107 of epoch 0
# Batch 107 of epoch 0, Loss: 2.0808255672454834
# Processing batch 108 of epoch 0
# Batch 108 of epoch 0, Loss: 2.0529568195343018
# Processing batch 109 of epoch 0
# Batch 109 of epoch 0, Loss: 2.103882312774658
# Processing batch 110 of epoch 0
# Batch 110 of epoch 0, Loss: 2.1988844871520996
# Processing batch 111 of epoch 0
# Batch 111 of epoch 0, Loss: 2.1810903549194336
# Processing batch 112 of epoch 0
# Batch 112 of epoch 0, Loss: 2.1700408458709717
# Processing batch 113 of epoch 0
# Batch 113 of epoch 0, Loss: 2.0738513469696045
# Processing batch 114 of epoch 0
# Batch 114 of epoch 0, Loss: 2.1280975341796875
# Processing batch 115 of epoch 0
# Batch 115 of epoch 0, Loss: 2.3214826583862305
# Processing batch 116 of epoch 0
# Batch 116 of epoch 0, Loss: 2.1515400409698486
# Processing batch 117 of epoch 0
# Batch 117 of epoch 0, Loss: 2.178715944290161
# Processing batch 118 of epoch 0
# Batch 118 of epoch 0, Loss: 2.2823996543884277
# Processing batch 119 of epoch 0
# Batch 119 of epoch 0, Loss: 2.2281055450439453
# Processing batch 120 of epoch 0
# Batch 120 of epoch 0, Loss: 2.1256446838378906
# Processing batch 121 of epoch 0
# Batch 121 of epoch 0, Loss: 2.1596975326538086
# Processing batch 122 of epoch 0
# Batch 122 of epoch 0, Loss: 2.146183729171753
# Processing batch 123 of epoch 0
# Batch 123 of epoch 0, Loss: 2.2071259021759033
# Processing batch 124 of epoch 0
# Batch 124 of epoch 0, Loss: 2.1471269130706787
# Processing batch 125 of epoch 0
# Batch 125 of epoch 0, Loss: 2.1270387172698975
# Processing batch 126 of epoch 0
# Batch 126 of epoch 0, Loss: 2.1504921913146973
# Processing batch 127 of epoch 0
# Batch 127 of epoch 0, Loss: 2.0942394733428955
# Processing batch 128 of epoch 0
# Batch 128 of epoch 0, Loss: 2.157017230987549
# Processing batch 129 of epoch 0
# Batch 129 of epoch 0, Loss: 2.167022705078125
# Processing batch 130 of epoch 0
# Batch 130 of epoch 0, Loss: 2.1494178771972656
# Processing batch 131 of epoch 0
# Batch 131 of epoch 0, Loss: 2.2307145595550537
# Processing batch 132 of epoch 0
# Batch 132 of epoch 0, Loss: 2.1394219398498535
# Processing batch 133 of epoch 0
# Batch 133 of epoch 0, Loss: 2.147226333618164
# Processing batch 134 of epoch 0
# Batch 134 of epoch 0, Loss: 2.1948044300079346
# Processing batch 135 of epoch 0
# Batch 135 of epoch 0, Loss: 2.1704680919647217
# Processing batch 136 of epoch 0
# Batch 136 of epoch 0, Loss: 2.1078391075134277
# Processing batch 137 of epoch 0
# Batch 137 of epoch 0, Loss: 2.152064085006714
# Processing batch 138 of epoch 0
# Batch 138 of epoch 0, Loss: 2.111788749694824
# Processing batch 139 of epoch 0
# Batch 139 of epoch 0, Loss: 1.9889988899230957
# Processing batch 140 of epoch 0
# Batch 140 of epoch 0, Loss: 2.1254165172576904
# Processing batch 141 of epoch 0
# Batch 141 of epoch 0, Loss: 2.099684238433838
# Processing batch 142 of epoch 0
# Batch 142 of epoch 0, Loss: 2.254060745239258
# Processing batch 143 of epoch 0
# Batch 143 of epoch 0, Loss: 2.046201705932617
# Processing batch 144 of epoch 0
# Batch 144 of epoch 0, Loss: 2.130420207977295
# Processing batch 145 of epoch 0
# Batch 145 of epoch 0, Loss: 2.1026804447174072
# Processing batch 146 of epoch 0
# Batch 146 of epoch 0, Loss: 2.132646322250366
# Processing batch 147 of epoch 0
# Batch 147 of epoch 0, Loss: 2.2508487701416016
# Processing batch 148 of epoch 0
# Batch 148 of epoch 0, Loss: 2.0211751461029053
# Processing batch 149 of epoch 0
# Batch 149 of epoch 0, Loss: 1.9978339672088623
# Processing batch 150 of epoch 0
# Batch 150 of epoch 0, Loss: 2.0664944648742676
# Processing batch 151 of epoch 0
# Batch 151 of epoch 0, Loss: 2.183439254760742
# Processing batch 152 of epoch 0
# Batch 152 of epoch 0, Loss: 1.9839003086090088
# Processing batch 153 of epoch 0
# Batch 153 of epoch 0, Loss: 2.0790088176727295
# Processing batch 154 of epoch 0
# Batch 154 of epoch 0, Loss: 2.1834681034088135
# Processing batch 155 of epoch 0
# Batch 155 of epoch 0, Loss: 2.297377824783325
# Processing batch 156 of epoch 0
# Batch 156 of epoch 0, Loss: 2.0241830348968506
# Processing batch 157 of epoch 0
# Batch 157 of epoch 0, Loss: 2.0788285732269287
# Processing batch 158 of epoch 0
# Batch 158 of epoch 0, Loss: 2.2007694244384766
# Processing batch 159 of epoch 0
# Batch 159 of epoch 0, Loss: 2.0867197513580322
# Processing batch 160 of epoch 0
# Batch 160 of epoch 0, Loss: 2.0988993644714355
# Processing batch 161 of epoch 0
# Batch 161 of epoch 0, Loss: 2.0742404460906982
# Processing batch 162 of epoch 0
# Batch 162 of epoch 0, Loss: 2.1294922828674316
# Processing batch 163 of epoch 0
# Batch 163 of epoch 0, Loss: 2.0728166103363037
# Processing batch 164 of epoch 0
# Batch 164 of epoch 0, Loss: 2.218834161758423
# Processing batch 165 of epoch 0
# Batch 165 of epoch 0, Loss: 2.0603342056274414
# Processing batch 166 of epoch 0
# Batch 166 of epoch 0, Loss: 2.0892434120178223
# Processing batch 167 of epoch 0
# Batch 167 of epoch 0, Loss: 1.989567756652832
# Processing batch 168 of epoch 0
# Batch 168 of epoch 0, Loss: 2.0867080688476562
# Processing batch 169 of epoch 0
# Batch 169 of epoch 0, Loss: 2.0400960445404053
# Processing batch 170 of epoch 0
# Batch 170 of epoch 0, Loss: 2.113074779510498
# Processing batch 171 of epoch 0
# Batch 171 of epoch 0, Loss: 2.0717966556549072
# Processing batch 172 of epoch 0
# Batch 172 of epoch 0, Loss: 2.0663092136383057
# Processing batch 173 of epoch 0
# Batch 173 of epoch 0, Loss: 2.0649168491363525
# Processing batch 174 of epoch 0
# Batch 174 of epoch 0, Loss: 2.157815456390381
# Processing batch 175 of epoch 0
# Batch 175 of epoch 0, Loss: 2.118762731552124
# Processing batch 176 of epoch 0
# Batch 176 of epoch 0, Loss: 2.134561777114868
# Processing batch 177 of epoch 0
# Batch 177 of epoch 0, Loss: 2.1714425086975098
# Processing batch 178 of epoch 0
# Batch 178 of epoch 0, Loss: 2.069735050201416
# Processing batch 179 of epoch 0
# Batch 179 of epoch 0, Loss: 2.1948747634887695
# Processing batch 180 of epoch 0
# Batch 180 of epoch 0, Loss: 2.046574354171753
# Processing batch 181 of epoch 0
# Batch 181 of epoch 0, Loss: 2.121263027191162
# Processing batch 182 of epoch 0
# Batch 182 of epoch 0, Loss: 1.9558360576629639
# Processing batch 183 of epoch 0
# Batch 183 of epoch 0, Loss: 1.9973911046981812
# Processing batch 184 of epoch 0
# Batch 184 of epoch 0, Loss: 2.045487403869629
# Processing batch 185 of epoch 0
# Batch 185 of epoch 0, Loss: 2.134477376937866
# Processing batch 186 of epoch 0
# Batch 186 of epoch 0, Loss: 2.2276854515075684
# Processing batch 187 of epoch 0
# Batch 187 of epoch 0, Loss: 1.8343470096588135
# Processing batch 188 of epoch 0
# Batch 188 of epoch 0, Loss: 1.9870628118515015
# Processing batch 189 of epoch 0
# Batch 189 of epoch 0, Loss: 2.037057399749756
# Processing batch 190 of epoch 0
# Batch 190 of epoch 0, Loss: 2.1017565727233887
# Processing batch 191 of epoch 0
# Batch 191 of epoch 0, Loss: 2.047795057296753
# Processing batch 192 of epoch 0
# Batch 192 of epoch 0, Loss: 2.03021240234375
# Processing batch 193 of epoch 0
# Batch 193 of epoch 0, Loss: 2.141418933868408
# Processing batch 194 of epoch 0
# Batch 194 of epoch 0, Loss: 2.0663909912109375
# Processing batch 195 of epoch 0
# Batch 195 of epoch 0, Loss: 2.1656806468963623
# Processing batch 196 of epoch 0
# Batch 196 of epoch 0, Loss: 2.120570182800293
# Processing batch 197 of epoch 0
# Batch 197 of epoch 0, Loss: 2.1019551753997803
# Processing batch 198 of epoch 0
# Batch 198 of epoch 0, Loss: 2.0288281440734863
# Processing batch 199 of epoch 0
# Batch 199 of epoch 0, Loss: 1.9284820556640625
# Processing batch 200 of epoch 0
# Batch 200 of epoch 0, Loss: 2.068819284439087
# Processing batch 201 of epoch 0
# Batch 201 of epoch 0, Loss: 1.9742985963821411
# Processing batch 202 of epoch 0
# Batch 202 of epoch 0, Loss: 1.9894981384277344
# Processing batch 203 of epoch 0
# Batch 203 of epoch 0, Loss: 2.0108249187469482
# Processing batch 204 of epoch 0
# Batch 204 of epoch 0, Loss: 2.025989294052124
# Processing batch 205 of epoch 0
# Batch 205 of epoch 0, Loss: 2.014556646347046
# Processing batch 206 of epoch 0
# Batch 206 of epoch 0, Loss: 2.0102834701538086
# Processing batch 207 of epoch 0
# Batch 207 of epoch 0, Loss: 2.1057510375976562
# Processing batch 208 of epoch 0
# Batch 208 of epoch 0, Loss: 2.08447265625
# Processing batch 209 of epoch 0
# Batch 209 of epoch 0, Loss: 2.0917792320251465
# Processing batch 210 of epoch 0
# Batch 210 of epoch 0, Loss: 1.9451881647109985
# Processing batch 211 of epoch 0
# Batch 211 of epoch 0, Loss: 2.0872678756713867
# Processing batch 212 of epoch 0
# Batch 212 of epoch 0, Loss: 2.1094512939453125
# Processing batch 213 of epoch 0
# Batch 213 of epoch 0, Loss: 2.055244207382202
# Processing batch 214 of epoch 0
# Batch 214 of epoch 0, Loss: 1.9583908319473267
# Processing batch 215 of epoch 0
# Batch 215 of epoch 0, Loss: 1.8844889402389526
# Processing batch 216 of epoch 0
# Batch 216 of epoch 0, Loss: 2.0005104541778564
# Processing batch 217 of epoch 0
# Batch 217 of epoch 0, Loss: 2.0411205291748047
# Processing batch 218 of epoch 0
# Batch 218 of epoch 0, Loss: 2.0458881855010986
# Processing batch 219 of epoch 0
# Batch 219 of epoch 0, Loss: 2.0655343532562256
# Processing batch 220 of epoch 0
# Batch 220 of epoch 0, Loss: 2.133165121078491
# Processing batch 221 of epoch 0
# Batch 221 of epoch 0, Loss: 2.0233352184295654
# Processing batch 222 of epoch 0
# Batch 222 of epoch 0, Loss: 2.101917028427124
# Processing batch 223 of epoch 0
# Batch 223 of epoch 0, Loss: 2.059866428375244
# Processing batch 224 of epoch 0
# Batch 224 of epoch 0, Loss: 2.124171495437622
# Processing batch 225 of epoch 0
# Batch 225 of epoch 0, Loss: 2.1519877910614014
# Processing batch 226 of epoch 0
# Batch 226 of epoch 0, Loss: 2.1169991493225098
# Processing batch 227 of epoch 0
# Batch 227 of epoch 0, Loss: 2.0094027519226074
# Processing batch 228 of epoch 0
# Batch 228 of epoch 0, Loss: 2.031360626220703
# Processing batch 229 of epoch 0
# Batch 229 of epoch 0, Loss: 2.048593282699585
# Processing batch 230 of epoch 0
# Batch 230 of epoch 0, Loss: 2.0828638076782227
# Processing batch 231 of epoch 0
# Batch 231 of epoch 0, Loss: 2.0004374980926514
# Processing batch 232 of epoch 0
# Batch 232 of epoch 0, Loss: 2.0548720359802246
# Processing batch 233 of epoch 0
# Batch 233 of epoch 0, Loss: 2.1116223335266113
# Processing batch 234 of epoch 0
# Batch 234 of epoch 0, Loss: 1.9283562898635864
# Processing batch 235 of epoch 0
# Batch 235 of epoch 0, Loss: 2.0330121517181396
# Processing batch 236 of epoch 0
# Batch 236 of epoch 0, Loss: 1.9906907081604004
# Processing batch 237 of epoch 0
# Batch 237 of epoch 0, Loss: 1.9000095129013062
# Processing batch 238 of epoch 0
# Batch 238 of epoch 0, Loss: 2.239809989929199
# Processing batch 239 of epoch 0
# Batch 239 of epoch 0, Loss: 2.106938600540161
# Processing batch 240 of epoch 0
# Batch 240 of epoch 0, Loss: 1.7808243036270142
# Processing batch 241 of epoch 0
# Batch 241 of epoch 0, Loss: 2.087908983230591
# Processing batch 242 of epoch 0
# Batch 242 of epoch 0, Loss: 1.9861619472503662
# Processing batch 243 of epoch 0
# Batch 243 of epoch 0, Loss: 2.010619640350342
# Processing batch 244 of epoch 0
# Batch 244 of epoch 0, Loss: 1.8417539596557617
# Processing batch 245 of epoch 0
# Batch 245 of epoch 0, Loss: 1.9396363496780396
# Processing batch 246 of epoch 0
# Batch 246 of epoch 0, Loss: 2.0065653324127197
# Processing batch 247 of epoch 0
# Batch 247 of epoch 0, Loss: 2.0000269412994385
# Processing batch 248 of epoch 0
# Batch 248 of epoch 0, Loss: 2.004798650741577
# Processing batch 249 of epoch 0
# Batch 249 of epoch 0, Loss: 1.798218846321106
# Processing batch 250 of epoch 0
# Batch 250 of epoch 0, Loss: 1.9544901847839355
# Processing batch 251 of epoch 0
# Batch 251 of epoch 0, Loss: 1.8700217008590698
# Processing batch 252 of epoch 0
# Batch 252 of epoch 0, Loss: 1.9665430784225464
# Processing batch 253 of epoch 0
# Batch 253 of epoch 0, Loss: 2.1266703605651855
# Processing batch 254 of epoch 0
# Batch 254 of epoch 0, Loss: 1.9044978618621826
# Processing batch 255 of epoch 0
# Batch 255 of epoch 0, Loss: 1.9709372520446777
# Processing batch 256 of epoch 0
# Batch 256 of epoch 0, Loss: 1.917313575744629
# Processing batch 257 of epoch 0
# Batch 257 of epoch 0, Loss: 1.9312161207199097
# Processing batch 258 of epoch 0
# Batch 258 of epoch 0, Loss: 1.8417781591415405
# Processing batch 259 of epoch 0
# Batch 259 of epoch 0, Loss: 2.0528852939605713
# Processing batch 260 of epoch 0
# Batch 260 of epoch 0, Loss: 1.9615478515625
# Processing batch 261 of epoch 0
# Batch 261 of epoch 0, Loss: 1.8901699781417847
# Processing batch 262 of epoch 0
# Batch 262 of epoch 0, Loss: 1.9195168018341064
# Processing batch 263 of epoch 0
# Batch 263 of epoch 0, Loss: 2.077587842941284
# Processing batch 264 of epoch 0
# Batch 264 of epoch 0, Loss: 1.9305920600891113
# Processing batch 265 of epoch 0
# Batch 265 of epoch 0, Loss: 1.9977452754974365
# Processing batch 266 of epoch 0
# Batch 266 of epoch 0, Loss: 1.9335881471633911
# Processing batch 267 of epoch 0
# Batch 267 of epoch 0, Loss: 2.10725736618042
# Processing batch 268 of epoch 0
# Batch 268 of epoch 0, Loss: 1.9579074382781982
# Processing batch 269 of epoch 0
# Batch 269 of epoch 0, Loss: 1.9738121032714844
# Processing batch 270 of epoch 0
# Batch 270 of epoch 0, Loss: 1.8743423223495483
# Processing batch 271 of epoch 0
# Batch 271 of epoch 0, Loss: 1.9654966592788696
# Processing batch 272 of epoch 0
# Batch 272 of epoch 0, Loss: 1.8445038795471191
# Processing batch 273 of epoch 0
# Batch 273 of epoch 0, Loss: 1.9868444204330444
# Processing batch 274 of epoch 0
# Batch 274 of epoch 0, Loss: 2.0143282413482666
# Processing batch 275 of epoch 0
# Batch 275 of epoch 0, Loss: 2.0198192596435547
# Processing batch 276 of epoch 0
# Batch 276 of epoch 0, Loss: 1.9492998123168945
# Processing batch 277 of epoch 0
# Batch 277 of epoch 0, Loss: 1.927899718284607
# Processing batch 278 of epoch 0
# Batch 278 of epoch 0, Loss: 2.2318689823150635
# Processing batch 279 of epoch 0
# Batch 279 of epoch 0, Loss: 2.019232988357544
# Processing batch 280 of epoch 0
# Batch 280 of epoch 0, Loss: 2.0151479244232178
# Processing batch 281 of epoch 0
# Batch 281 of epoch 0, Loss: 1.978794813156128
# Processing batch 282 of epoch 0
# Batch 282 of epoch 0, Loss: 1.8604258298873901
# Processing batch 283 of epoch 0
# Batch 283 of epoch 0, Loss: 2.063295364379883
# Processing batch 284 of epoch 0
# Batch 284 of epoch 0, Loss: 1.9498289823532104
# Processing batch 285 of epoch 0
# Batch 285 of epoch 0, Loss: 2.057985782623291
# Processing batch 286 of epoch 0
# Batch 286 of epoch 0, Loss: 2.092287063598633
# Processing batch 287 of epoch 0
# Batch 287 of epoch 0, Loss: 1.9608850479125977
# Processing batch 288 of epoch 0
# Batch 288 of epoch 0, Loss: 1.8699593544006348
# Processing batch 289 of epoch 0
# Batch 289 of epoch 0, Loss: 2.145360231399536
# Processing batch 290 of epoch 0
# Batch 290 of epoch 0, Loss: 1.9631297588348389
# Processing batch 291 of epoch 0
# Batch 291 of epoch 0, Loss: 1.8605518341064453
# Processing batch 292 of epoch 0
# Batch 292 of epoch 0, Loss: 2.038917064666748
# Processing batch 293 of epoch 0
# Batch 293 of epoch 0, Loss: 2.095402717590332
# Processing batch 294 of epoch 0
# Batch 294 of epoch 0, Loss: 1.8965963125228882
# Processing batch 295 of epoch 0
# Batch 295 of epoch 0, Loss: 1.8089205026626587
# Processing batch 296 of epoch 0
# Batch 296 of epoch 0, Loss: 1.8292832374572754
# Processing batch 297 of epoch 0
# Batch 297 of epoch 0, Loss: 1.8242437839508057
# Processing batch 298 of epoch 0
# Batch 298 of epoch 0, Loss: 1.9484941959381104
# Processing batch 299 of epoch 0
# Batch 299 of epoch 0, Loss: 1.9168901443481445
# Processing batch 300 of epoch 0
# Batch 300 of epoch 0, Loss: 2.102691173553467
# Processing batch 301 of epoch 0
# Batch 301 of epoch 0, Loss: 1.9558775424957275
# Processing batch 302 of epoch 0
# Batch 302 of epoch 0, Loss: 1.825089931488037
# Processing batch 303 of epoch 0
# Batch 303 of epoch 0, Loss: 1.9847432374954224
# Processing batch 304 of epoch 0
# Batch 304 of epoch 0, Loss: 1.8339332342147827
# Processing batch 305 of epoch 0
# Batch 305 of epoch 0, Loss: 1.9169549942016602
# Processing batch 306 of epoch 0
# Batch 306 of epoch 0, Loss: 2.0079731941223145
# Processing batch 307 of epoch 0
# Batch 307 of epoch 0, Loss: 1.871384620666504
# Processing batch 308 of epoch 0
# Batch 308 of epoch 0, Loss: 1.8387006521224976
# Processing batch 309 of epoch 0
# Batch 309 of epoch 0, Loss: 1.9650782346725464
# Processing batch 310 of epoch 0
# Batch 310 of epoch 0, Loss: 1.928067922592163
# Processing batch 311 of epoch 0
# Batch 311 of epoch 0, Loss: 1.8164124488830566
# Processing batch 312 of epoch 0
# Batch 312 of epoch 0, Loss: 2.0082335472106934
# Processing batch 313 of epoch 0
# Batch 313 of epoch 0, Loss: 1.8844313621520996
# Processing batch 314 of epoch 0
# Batch 314 of epoch 0, Loss: 1.8634148836135864
# Processing batch 315 of epoch 0
# Batch 315 of epoch 0, Loss: 1.8510932922363281
# Processing batch 316 of epoch 0
# Batch 316 of epoch 0, Loss: 2.0656380653381348
# Processing batch 317 of epoch 0
# Batch 317 of epoch 0, Loss: 1.8905836343765259
# Processing batch 318 of epoch 0
# Batch 318 of epoch 0, Loss: 1.8694615364074707
# Processing batch 319 of epoch 0
# Batch 319 of epoch 0, Loss: 2.054523468017578
# Processing batch 320 of epoch 0
# Batch 320 of epoch 0, Loss: 2.0622737407684326
# Processing batch 321 of epoch 0
# Batch 321 of epoch 0, Loss: 1.9914389848709106
# Processing batch 322 of epoch 0
# Batch 322 of epoch 0, Loss: 1.8315109014511108
# Processing batch 323 of epoch 0
# Batch 323 of epoch 0, Loss: 2.000643491744995
# Processing batch 324 of epoch 0
# Batch 324 of epoch 0, Loss: 1.8882267475128174
# Processing batch 325 of epoch 0
# Batch 325 of epoch 0, Loss: 2.0588934421539307
# Processing batch 326 of epoch 0
# Batch 326 of epoch 0, Loss: 2.06107234954834
# Processing batch 327 of epoch 0
# Batch 327 of epoch 0, Loss: 1.8909095525741577
# Processing batch 328 of epoch 0
# Batch 328 of epoch 0, Loss: 1.7725038528442383
# Processing batch 329 of epoch 0
# Batch 329 of epoch 0, Loss: 1.9145976305007935
# Processing batch 330 of epoch 0
# Batch 330 of epoch 0, Loss: 1.8748549222946167
# Processing batch 331 of epoch 0
# Batch 331 of epoch 0, Loss: 1.9699039459228516
# Processing batch 332 of epoch 0
# Batch 332 of epoch 0, Loss: 2.0909271240234375
# Processing batch 333 of epoch 0
# Batch 333 of epoch 0, Loss: 1.9023839235305786
# Processing batch 334 of epoch 0
# Batch 334 of epoch 0, Loss: 1.9424796104431152
# Processing batch 335 of epoch 0
# Batch 335 of epoch 0, Loss: 1.8978254795074463
# Processing batch 336 of epoch 0
# Batch 336 of epoch 0, Loss: 1.9645169973373413
# Processing batch 337 of epoch 0
# Batch 337 of epoch 0, Loss: 1.8869723081588745
# Processing batch 338 of epoch 0
# Batch 338 of epoch 0, Loss: 1.861784815788269
# Processing batch 339 of epoch 0
# Batch 339 of epoch 0, Loss: 1.8917224407196045
# Processing batch 340 of epoch 0
# Batch 340 of epoch 0, Loss: 1.8532798290252686
# Processing batch 341 of epoch 0
# Batch 341 of epoch 0, Loss: 1.7642109394073486
# Processing batch 342 of epoch 0
# Batch 342 of epoch 0, Loss: 1.8369114398956299
# Processing batch 343 of epoch 0
# Batch 343 of epoch 0, Loss: 1.9909573793411255
# Processing batch 344 of epoch 0
# Batch 344 of epoch 0, Loss: 1.9534372091293335
# Processing batch 345 of epoch 0
# Batch 345 of epoch 0, Loss: 2.02921462059021
# Processing batch 346 of epoch 0
# Batch 346 of epoch 0, Loss: 1.9456652402877808
# Processing batch 347 of epoch 0
# Batch 347 of epoch 0, Loss: 2.0682175159454346
# Processing batch 348 of epoch 0
# Batch 348 of epoch 0, Loss: 1.8254178762435913
# Processing batch 349 of epoch 0
# Batch 349 of epoch 0, Loss: 1.744536280632019
# Processing batch 350 of epoch 0
# Batch 350 of epoch 0, Loss: 1.9581327438354492
# Processing batch 351 of epoch 0
# Batch 351 of epoch 0, Loss: 2.123380422592163
# Processing batch 352 of epoch 0
# Batch 352 of epoch 0, Loss: 1.9571994543075562
# Processing batch 353 of epoch 0
# Batch 353 of epoch 0, Loss: 1.9956958293914795
# Processing batch 354 of epoch 0
# Batch 354 of epoch 0, Loss: 1.734359860420227
# Processing batch 355 of epoch 0
# Batch 355 of epoch 0, Loss: 2.0219314098358154
# Processing batch 356 of epoch 0
# Batch 356 of epoch 0, Loss: 1.8616178035736084
# Processing batch 357 of epoch 0
# Batch 357 of epoch 0, Loss: 1.9656788110733032
# Processing batch 358 of epoch 0
# Batch 358 of epoch 0, Loss: 2.0197794437408447
# Processing batch 359 of epoch 0
# Batch 359 of epoch 0, Loss: 1.9188306331634521
# Processing batch 360 of epoch 0
# Batch 360 of epoch 0, Loss: 2.1307175159454346
# Processing batch 361 of epoch 0
# Batch 361 of epoch 0, Loss: 1.9525843858718872
# Processing batch 362 of epoch 0
# Batch 362 of epoch 0, Loss: 1.796057939529419
# Processing batch 363 of epoch 0
# Batch 363 of epoch 0, Loss: 1.9731425046920776
# Processing batch 364 of epoch 0
# Batch 364 of epoch 0, Loss: 2.076598882675171
# Processing batch 365 of epoch 0
# Batch 365 of epoch 0, Loss: 1.8850258588790894
# Processing batch 366 of epoch 0
# Batch 366 of epoch 0, Loss: 1.8984835147857666
# Processing batch 367 of epoch 0
# Batch 367 of epoch 0, Loss: 1.753781795501709
# Processing batch 368 of epoch 0
# Batch 368 of epoch 0, Loss: 1.836401104927063
# Processing batch 369 of epoch 0
# Batch 369 of epoch 0, Loss: 2.0044431686401367
# Processing batch 370 of epoch 0
# Batch 370 of epoch 0, Loss: 1.8393263816833496
# Processing batch 371 of epoch 0
# Batch 371 of epoch 0, Loss: 1.8305236101150513
# Processing batch 372 of epoch 0
# Batch 372 of epoch 0, Loss: 1.9924196004867554
# Processing batch 373 of epoch 0
# Batch 373 of epoch 0, Loss: 1.9338845014572144
# Processing batch 374 of epoch 0
# Batch 374 of epoch 0, Loss: 1.9129586219787598
# Processing batch 375 of epoch 0
# Batch 375 of epoch 0, Loss: 1.812109351158142
# Processing batch 376 of epoch 0
# Batch 376 of epoch 0, Loss: 1.7476471662521362
# Processing batch 377 of epoch 0
# Batch 377 of epoch 0, Loss: 1.5873585939407349
# Processing batch 378 of epoch 0
# Batch 378 of epoch 0, Loss: 1.7981854677200317
# Processing batch 379 of epoch 0
# Batch 379 of epoch 0, Loss: 1.8134387731552124
# Processing batch 380 of epoch 0
# Batch 380 of epoch 0, Loss: 1.7814321517944336
# Processing batch 381 of epoch 0
# Batch 381 of epoch 0, Loss: 2.095838785171509
# Processing batch 382 of epoch 0
# Batch 382 of epoch 0, Loss: 1.938397765159607
# Processing batch 383 of epoch 0
# Batch 383 of epoch 0, Loss: 1.8606408834457397
# Processing batch 384 of epoch 0
# Batch 384 of epoch 0, Loss: 1.7823479175567627
# Processing batch 385 of epoch 0
# Batch 385 of epoch 0, Loss: 1.9211763143539429
# Processing batch 386 of epoch 0
# Batch 386 of epoch 0, Loss: 1.7366338968276978
# Processing batch 387 of epoch 0
# Batch 387 of epoch 0, Loss: 1.7762579917907715
# Processing batch 388 of epoch 0
# Batch 388 of epoch 0, Loss: 2.0005500316619873
# Processing batch 389 of epoch 0
# Batch 389 of epoch 0, Loss: 1.8129273653030396
# Processing batch 390 of epoch 0
# Batch 390 of epoch 0, Loss: 1.8673150539398193
# Processing batch 391 of epoch 0
# Batch 391 of epoch 0, Loss: 1.9268641471862793
# Processing batch 392 of epoch 0
# Batch 392 of epoch 0, Loss: 1.8517171144485474
# Processing batch 393 of epoch 0
# Batch 393 of epoch 0, Loss: 1.8853745460510254
# Processing batch 394 of epoch 0
# Batch 394 of epoch 0, Loss: 1.8626937866210938
# Processing batch 395 of epoch 0
# Batch 395 of epoch 0, Loss: 1.7856218814849854
# Processing batch 396 of epoch 0
# Batch 396 of epoch 0, Loss: 1.8509459495544434
# Processing batch 397 of epoch 0
# Batch 397 of epoch 0, Loss: 1.896417260169983
# Processing batch 398 of epoch 0
# Batch 398 of epoch 0, Loss: 2.0701799392700195
# Processing batch 399 of epoch 0
# Batch 399 of epoch 0, Loss: 1.8377565145492554
# Processing batch 400 of epoch 0
# Batch 400 of epoch 0, Loss: 1.7505635023117065
# Processing batch 401 of epoch 0
# Batch 401 of epoch 0, Loss: 1.7891017198562622
# Processing batch 402 of epoch 0
# Batch 402 of epoch 0, Loss: 1.9213413000106812
# Processing batch 403 of epoch 0
# Batch 403 of epoch 0, Loss: 1.844992756843567
# Processing batch 404 of epoch 0
# Batch 404 of epoch 0, Loss: 1.7837591171264648
# Processing batch 405 of epoch 0
# Batch 405 of epoch 0, Loss: 1.8332724571228027
# Processing batch 406 of epoch 0
# Batch 406 of epoch 0, Loss: 1.9152417182922363
# Processing batch 407 of epoch 0
# Batch 407 of epoch 0, Loss: 1.8318935632705688
# Processing batch 408 of epoch 0
# Batch 408 of epoch 0, Loss: 1.7469583749771118
# Processing batch 409 of epoch 0
# Batch 409 of epoch 0, Loss: 1.802996277809143
# Processing batch 410 of epoch 0
# Batch 410 of epoch 0, Loss: 2.0375075340270996
# Processing batch 411 of epoch 0
# Batch 411 of epoch 0, Loss: 1.8172005414962769
# Processing batch 412 of epoch 0
# Batch 412 of epoch 0, Loss: 1.932854175567627
# Processing batch 413 of epoch 0
# Batch 413 of epoch 0, Loss: 1.9450985193252563
# Processing batch 414 of epoch 0
# Batch 414 of epoch 0, Loss: 1.8886325359344482
# Processing batch 415 of epoch 0
# Batch 415 of epoch 0, Loss: 1.655210018157959
# Processing batch 416 of epoch 0
# Batch 416 of epoch 0, Loss: 2.0327107906341553
# Processing batch 417 of epoch 0
# Batch 417 of epoch 0, Loss: 1.7550594806671143
# Processing batch 418 of epoch 0
# Batch 418 of epoch 0, Loss: 1.6718491315841675
# Processing batch 419 of epoch 0
# Batch 419 of epoch 0, Loss: 1.9867043495178223
# Processing batch 420 of epoch 0
# Batch 420 of epoch 0, Loss: 1.8438313007354736
# Processing batch 421 of epoch 0
# Batch 421 of epoch 0, Loss: 1.688938856124878
# Processing batch 422 of epoch 0
# Batch 422 of epoch 0, Loss: 1.8151627779006958
# Processing batch 423 of epoch 0
# Batch 423 of epoch 0, Loss: 1.7843539714813232
# Processing batch 424 of epoch 0
# Batch 424 of epoch 0, Loss: 2.022444486618042
# Processing batch 425 of epoch 0
# Batch 425 of epoch 0, Loss: 1.883058786392212
# Processing batch 426 of epoch 0
# Batch 426 of epoch 0, Loss: 1.928748607635498
# Processing batch 427 of epoch 0
# Batch 427 of epoch 0, Loss: 2.024686574935913
# Processing batch 428 of epoch 0
# Batch 428 of epoch 0, Loss: 1.7329838275909424
# Processing batch 429 of epoch 0
# Batch 429 of epoch 0, Loss: 1.848076343536377
# Processing batch 430 of epoch 0
# Batch 430 of epoch 0, Loss: 1.8486359119415283
# Processing batch 431 of epoch 0
# Batch 431 of epoch 0, Loss: 1.9839420318603516
# Processing batch 432 of epoch 0
# Batch 432 of epoch 0, Loss: 1.8854156732559204
# Processing batch 433 of epoch 0
# Batch 433 of epoch 0, Loss: 1.9823522567749023
# Processing batch 434 of epoch 0
# Batch 434 of epoch 0, Loss: 1.8966022729873657
# Processing batch 435 of epoch 0
# Batch 435 of epoch 0, Loss: 1.802181363105774
# Processing batch 436 of epoch 0
# Batch 436 of epoch 0, Loss: 1.8757727146148682
# Processing batch 437 of epoch 0
# Batch 437 of epoch 0, Loss: 1.751306414604187
# Processing batch 438 of epoch 0
# Batch 438 of epoch 0, Loss: 1.963027834892273
# Processing batch 439 of epoch 0
# Batch 439 of epoch 0, Loss: 1.736860752105713
# Processing batch 440 of epoch 0
# Batch 440 of epoch 0, Loss: 1.8377186059951782
# Processing batch 441 of epoch 0
# Batch 441 of epoch 0, Loss: 1.9726866483688354
# Processing batch 442 of epoch 0
# Batch 442 of epoch 0, Loss: 1.983700156211853
# Processing batch 443 of epoch 0
# Batch 443 of epoch 0, Loss: 1.9407895803451538
# Processing batch 444 of epoch 0
# Batch 444 of epoch 0, Loss: 1.8295661211013794
# Processing batch 445 of epoch 0
# Batch 445 of epoch 0, Loss: 1.6732960939407349
# Processing batch 446 of epoch 0
# Batch 446 of epoch 0, Loss: 1.8406813144683838
# Processing batch 447 of epoch 0
# Batch 447 of epoch 0, Loss: 1.8149696588516235
# Processing batch 448 of epoch 0
# Batch 448 of epoch 0, Loss: 1.785986065864563
# Processing batch 449 of epoch 0
# Batch 449 of epoch 0, Loss: 1.8332291841506958
# Processing batch 450 of epoch 0
# Batch 450 of epoch 0, Loss: 1.79120934009552
# Processing batch 451 of epoch 0
# Batch 451 of epoch 0, Loss: 1.8632439374923706
# Processing batch 452 of epoch 0
# Batch 452 of epoch 0, Loss: 1.937041997909546
# Processing batch 453 of epoch 0
# Batch 453 of epoch 0, Loss: 1.9126546382904053
# Processing batch 454 of epoch 0
# Batch 454 of epoch 0, Loss: 1.861799716949463
# Processing batch 455 of epoch 0
# Batch 455 of epoch 0, Loss: 1.8004728555679321
# Processing batch 456 of epoch 0
# Batch 456 of epoch 0, Loss: 1.8851901292800903
# Processing batch 457 of epoch 0
# Batch 457 of epoch 0, Loss: 2.0321767330169678
# Processing batch 458 of epoch 0
# Batch 458 of epoch 0, Loss: 1.8155498504638672
# Processing batch 459 of epoch 0
# Batch 459 of epoch 0, Loss: 1.6804885864257812
# Processing batch 460 of epoch 0
# Batch 460 of epoch 0, Loss: 1.800291657447815
# Processing batch 461 of epoch 0
# Batch 461 of epoch 0, Loss: 1.8349453210830688
# Processing batch 462 of epoch 0
# Batch 462 of epoch 0, Loss: 1.826714038848877
# Processing batch 463 of epoch 0
# Batch 463 of epoch 0, Loss: 1.681453824043274
# Processing batch 464 of epoch 0
# Batch 464 of epoch 0, Loss: 1.9562749862670898
# Processing batch 465 of epoch 0
# Batch 465 of epoch 0, Loss: 1.826762080192566
# Processing batch 466 of epoch 0
# Batch 466 of epoch 0, Loss: 1.7982323169708252
# Processing batch 467 of epoch 0
# Batch 467 of epoch 0, Loss: 1.7874983549118042
# Processing batch 468 of epoch 0
# Batch 468 of epoch 0, Loss: 1.6564005613327026
# Processing batch 469 of epoch 0
# Batch 469 of epoch 0, Loss: 1.8143959045410156
# Processing batch 470 of epoch 0
# Batch 470 of epoch 0, Loss: 1.6772910356521606
# Processing batch 471 of epoch 0
# Batch 471 of epoch 0, Loss: 1.6009547710418701
# Processing batch 472 of epoch 0
# Batch 472 of epoch 0, Loss: 1.7884055376052856
# Processing batch 473 of epoch 0
# Batch 473 of epoch 0, Loss: 1.7994345426559448
# Processing batch 474 of epoch 0
# Batch 474 of epoch 0, Loss: 1.637169361114502
# Processing batch 475 of epoch 0
# Batch 475 of epoch 0, Loss: 1.838805079460144
# Processing batch 476 of epoch 0
# Batch 476 of epoch 0, Loss: 1.8802660703659058
# Processing batch 477 of epoch 0
# Batch 477 of epoch 0, Loss: 1.935932993888855
# Processing batch 478 of epoch 0
# Batch 478 of epoch 0, Loss: 1.8882766962051392
# Processing batch 479 of epoch 0
# Batch 479 of epoch 0, Loss: 1.9873764514923096
# Processing batch 480 of epoch 0
# Batch 480 of epoch 0, Loss: 1.5945907831192017
# Processing batch 481 of epoch 0
# Batch 481 of epoch 0, Loss: 1.8400285243988037
# Processing batch 482 of epoch 0
# Batch 482 of epoch 0, Loss: 1.759468674659729
# Processing batch 483 of epoch 0
# Batch 483 of epoch 0, Loss: 1.74722421169281
# Processing batch 484 of epoch 0
# Batch 484 of epoch 0, Loss: 1.7643615007400513
# Processing batch 485 of epoch 0
# Batch 485 of epoch 0, Loss: 1.8796396255493164
# Processing batch 486 of epoch 0
# Batch 486 of epoch 0, Loss: 1.8130240440368652
# Processing batch 487 of epoch 0
# Batch 487 of epoch 0, Loss: 1.8375152349472046
# Processing batch 488 of epoch 0
# Batch 488 of epoch 0, Loss: 1.74513840675354
# Processing batch 489 of epoch 0
# Batch 489 of epoch 0, Loss: 1.8293839693069458
# Processing batch 490 of epoch 0
# Batch 490 of epoch 0, Loss: 1.7963329553604126
# Processing batch 491 of epoch 0
# Batch 491 of epoch 0, Loss: 1.582573652267456
# Processing batch 492 of epoch 0
# Batch 492 of epoch 0, Loss: 1.5779227018356323
# Processing batch 493 of epoch 0
# Batch 493 of epoch 0, Loss: 1.6563708782196045
# Processing batch 494 of epoch 0
# Batch 494 of epoch 0, Loss: 1.7684636116027832
# Processing batch 495 of epoch 0
# Batch 495 of epoch 0, Loss: 1.8442742824554443
# Processing batch 496 of epoch 0
# Batch 496 of epoch 0, Loss: 1.757277488708496
# Processing batch 497 of epoch 0
# Batch 497 of epoch 0, Loss: 1.674001693725586
# Processing batch 498 of epoch 0
# Batch 498 of epoch 0, Loss: 1.7213159799575806
# Processing batch 499 of epoch 0
# Batch 499 of epoch 0, Loss: 1.7895760536193848
# Processing batch 500 of epoch 0
# Batch 500 of epoch 0, Loss: 1.8149001598358154
# Processing batch 501 of epoch 0
# Batch 501 of epoch 0, Loss: 1.747862696647644
# Processing batch 502 of epoch 0
# Batch 502 of epoch 0, Loss: 1.7826882600784302
# Processing batch 503 of epoch 0
# Batch 503 of epoch 0, Loss: 1.9342190027236938
# Processing batch 504 of epoch 0
# Batch 504 of epoch 0, Loss: 1.801061749458313
# Processing batch 505 of epoch 0
# Batch 505 of epoch 0, Loss: 1.8813897371292114
# Processing batch 506 of epoch 0
# Batch 506 of epoch 0, Loss: 1.7775899171829224
# Processing batch 507 of epoch 0
# Batch 507 of epoch 0, Loss: 1.9276330471038818
# Processing batch 508 of epoch 0
# Batch 508 of epoch 0, Loss: 1.7266231775283813
# Processing batch 509 of epoch 0
# Batch 509 of epoch 0, Loss: 1.6888149976730347
# Processing batch 510 of epoch 0
# Batch 510 of epoch 0, Loss: 1.7434284687042236
# Processing batch 511 of epoch 0
# Batch 511 of epoch 0, Loss: 1.7842168807983398
# Processing batch 512 of epoch 0
# Batch 512 of epoch 0, Loss: 1.7150589227676392
# Processing batch 513 of epoch 0
# Batch 513 of epoch 0, Loss: 1.765134572982788
# Processing batch 514 of epoch 0
# Batch 514 of epoch 0, Loss: 1.6326781511306763
# Processing batch 515 of epoch 0
# Batch 515 of epoch 0, Loss: 2.056178331375122
# Processing batch 516 of epoch 0
# Batch 516 of epoch 0, Loss: 1.8587476015090942
# Processing batch 517 of epoch 0
# Batch 517 of epoch 0, Loss: 2.021122932434082
# Processing batch 518 of epoch 0
# Batch 518 of epoch 0, Loss: 1.7056832313537598
# Processing batch 519 of epoch 0
# Batch 519 of epoch 0, Loss: 1.7552342414855957
# Processing batch 520 of epoch 0
# Batch 520 of epoch 0, Loss: 1.950844168663025
# Processing batch 521 of epoch 0
# Batch 521 of epoch 0, Loss: 1.752835750579834
# Processing batch 522 of epoch 0
# Batch 522 of epoch 0, Loss: 1.7381670475006104
# Processing batch 523 of epoch 0
# Batch 523 of epoch 0, Loss: 1.7922779321670532
# Processing batch 524 of epoch 0
# Batch 524 of epoch 0, Loss: 1.6451737880706787
# Processing batch 525 of epoch 0
# Batch 525 of epoch 0, Loss: 1.5848630666732788
# Processing batch 526 of epoch 0
# Batch 526 of epoch 0, Loss: 1.6553794145584106
# Processing batch 527 of epoch 0
# Batch 527 of epoch 0, Loss: 2.057246208190918
# Processing batch 528 of epoch 0
# Batch 528 of epoch 0, Loss: 1.7704309225082397
# Processing batch 529 of epoch 0
# Batch 529 of epoch 0, Loss: 1.7345025539398193
# Processing batch 530 of epoch 0
# Batch 530 of epoch 0, Loss: 1.8998777866363525
# Processing batch 531 of epoch 0
# Batch 531 of epoch 0, Loss: 1.833794116973877
# Processing batch 532 of epoch 0
# Batch 532 of epoch 0, Loss: 1.900902509689331
# Processing batch 533 of epoch 0
# Batch 533 of epoch 0, Loss: 1.8781694173812866
# Processing batch 534 of epoch 0
# Batch 534 of epoch 0, Loss: 1.647697925567627
# Processing batch 535 of epoch 0
# Batch 535 of epoch 0, Loss: 1.8697255849838257
# Processing batch 536 of epoch 0
# Batch 536 of epoch 0, Loss: 1.6183702945709229
# Processing batch 537 of epoch 0
# Batch 537 of epoch 0, Loss: 1.6921979188919067
# Processing batch 538 of epoch 0
# Batch 538 of epoch 0, Loss: 1.6266727447509766
# Processing batch 539 of epoch 0
# Batch 539 of epoch 0, Loss: 1.8520866632461548
# Processing batch 540 of epoch 0
# Batch 540 of epoch 0, Loss: 1.812597393989563
# Processing batch 541 of epoch 0
# Batch 541 of epoch 0, Loss: 1.898536205291748
# Processing batch 542 of epoch 0
# Batch 542 of epoch 0, Loss: 1.888490915298462
# Processing batch 543 of epoch 0
# Batch 543 of epoch 0, Loss: 1.75049889087677
# Processing batch 544 of epoch 0
# Batch 544 of epoch 0, Loss: 1.7510541677474976
# Processing batch 545 of epoch 0
# Batch 545 of epoch 0, Loss: 1.7681231498718262
# Processing batch 546 of epoch 0
# Batch 546 of epoch 0, Loss: 1.768574595451355
# Processing batch 547 of epoch 0
# Batch 547 of epoch 0, Loss: 1.870589017868042
# Processing batch 548 of epoch 0
# Batch 548 of epoch 0, Loss: 1.8487738370895386
# Processing batch 549 of epoch 0
# Batch 549 of epoch 0, Loss: 1.706020474433899
# Processing batch 550 of epoch 0
# Batch 550 of epoch 0, Loss: 1.8103758096694946
# Processing batch 551 of epoch 0
# Batch 551 of epoch 0, Loss: 1.916548490524292
# Processing batch 552 of epoch 0
# Batch 552 of epoch 0, Loss: 1.912544846534729
# Processing batch 553 of epoch 0
# Batch 553 of epoch 0, Loss: 1.7839020490646362
# Processing batch 554 of epoch 0
# Batch 554 of epoch 0, Loss: 1.7432818412780762
# Processing batch 555 of epoch 0
# Batch 555 of epoch 0, Loss: 1.9337339401245117
# Processing batch 556 of epoch 0
# Batch 556 of epoch 0, Loss: 1.8712530136108398
# Processing batch 557 of epoch 0
# Batch 557 of epoch 0, Loss: 1.659964680671692
# Processing batch 558 of epoch 0
# Batch 558 of epoch 0, Loss: 1.88992178440094
# Processing batch 559 of epoch 0
# Batch 559 of epoch 0, Loss: 1.7429293394088745
# Processing batch 560 of epoch 0
# Batch 560 of epoch 0, Loss: 1.9964855909347534
# Processing batch 561 of epoch 0
# Batch 561 of epoch 0, Loss: 1.827705979347229
# Processing batch 562 of epoch 0
# Batch 562 of epoch 0, Loss: 1.7951401472091675
# Processing batch 563 of epoch 0
# Batch 563 of epoch 0, Loss: 1.9587925672531128
# Processing batch 564 of epoch 0
# Batch 564 of epoch 0, Loss: 1.7524899244308472
# Processing batch 565 of epoch 0
# Batch 565 of epoch 0, Loss: 1.7784608602523804
# Processing batch 566 of epoch 0
# Batch 566 of epoch 0, Loss: 1.7980310916900635
# Processing batch 567 of epoch 0
# Batch 567 of epoch 0, Loss: 1.7577483654022217
# Processing batch 568 of epoch 0
# Batch 568 of epoch 0, Loss: 1.9529030323028564
# Processing batch 569 of epoch 0
# Batch 569 of epoch 0, Loss: 1.642843246459961
# Processing batch 570 of epoch 0
# Batch 570 of epoch 0, Loss: 1.7768874168395996
# Processing batch 571 of epoch 0
# Batch 571 of epoch 0, Loss: 1.7047756910324097
# Processing batch 572 of epoch 0
# Batch 572 of epoch 0, Loss: 1.7286550998687744
# Processing batch 573 of epoch 0
# Batch 573 of epoch 0, Loss: 1.6365970373153687
# Processing batch 574 of epoch 0
# Batch 574 of epoch 0, Loss: 1.7283388376235962
# Processing batch 575 of epoch 0
# Batch 575 of epoch 0, Loss: 2.031043291091919
# Processing batch 576 of epoch 0
# Batch 576 of epoch 0, Loss: 1.6171274185180664
# Processing batch 577 of epoch 0
# Batch 577 of epoch 0, Loss: 1.8392457962036133
# Processing batch 578 of epoch 0
# Batch 578 of epoch 0, Loss: 1.7497344017028809
# Processing batch 579 of epoch 0
# Batch 579 of epoch 0, Loss: 1.8603299856185913
# Processing batch 580 of epoch 0
# Batch 580 of epoch 0, Loss: 1.8265571594238281
# Processing batch 581 of epoch 0
# Batch 581 of epoch 0, Loss: 2.0686686038970947
# Processing batch 582 of epoch 0
# Batch 582 of epoch 0, Loss: 1.9160940647125244
# Processing batch 583 of epoch 0
# Batch 583 of epoch 0, Loss: 1.6158708333969116
# Processing batch 584 of epoch 0
# Batch 584 of epoch 0, Loss: 1.7957459688186646
# Processing batch 585 of epoch 0
# Batch 585 of epoch 0, Loss: 1.6864402294158936
# Processing batch 586 of epoch 0
# Batch 586 of epoch 0, Loss: 1.8387131690979004
# Processing batch 587 of epoch 0
# Batch 587 of epoch 0, Loss: 1.616761565208435
# Processing batch 588 of epoch 0
# Batch 588 of epoch 0, Loss: 1.571258544921875
# Processing batch 589 of epoch 0
# Batch 589 of epoch 0, Loss: 1.974366307258606
# Processing batch 590 of epoch 0
# Batch 590 of epoch 0, Loss: 1.8862022161483765
# Processing batch 591 of epoch 0
# Batch 591 of epoch 0, Loss: 1.7785422801971436
# Processing batch 592 of epoch 0
# Batch 592 of epoch 0, Loss: 1.751449465751648
# Processing batch 593 of epoch 0
# Batch 593 of epoch 0, Loss: 1.4640144109725952
# Processing batch 594 of epoch 0
# Batch 594 of epoch 0, Loss: 2.0470285415649414
# Processing batch 595 of epoch 0
# Batch 595 of epoch 0, Loss: 1.7526540756225586
# Processing batch 596 of epoch 0
# Batch 596 of epoch 0, Loss: 1.8471481800079346
# Processing batch 597 of epoch 0
# Batch 597 of epoch 0, Loss: 1.5642368793487549
# Processing batch 598 of epoch 0
# Batch 598 of epoch 0, Loss: 1.545496940612793
# Processing batch 599 of epoch 0
# Batch 599 of epoch 0, Loss: 1.6632637977600098
# Processing batch 600 of epoch 0
# Batch 600 of epoch 0, Loss: 1.7538464069366455
# Processing batch 601 of epoch 0
# Batch 601 of epoch 0, Loss: 1.9366360902786255
# Processing batch 602 of epoch 0
# Batch 602 of epoch 0, Loss: 1.78318452835083
# Processing batch 603 of epoch 0
# Batch 603 of epoch 0, Loss: 1.7330583333969116
# Processing batch 604 of epoch 0
# Batch 604 of epoch 0, Loss: 1.7691377401351929
# Processing batch 605 of epoch 0
# Batch 605 of epoch 0, Loss: 1.975565791130066
# Processing batch 606 of epoch 0
# Batch 606 of epoch 0, Loss: 1.6473828554153442
# Processing batch 607 of epoch 0
# Batch 607 of epoch 0, Loss: 1.6497255563735962
# Processing batch 608 of epoch 0
# Batch 608 of epoch 0, Loss: 1.6957080364227295
# Processing batch 609 of epoch 0
# Batch 609 of epoch 0, Loss: 1.8650308847427368
# Processing batch 610 of epoch 0
# Batch 610 of epoch 0, Loss: 1.7362927198410034
# Processing batch 611 of epoch 0
# Batch 611 of epoch 0, Loss: 1.7752304077148438
# ...
# Processing batch 671 of epoch 2
# Batch 671 of epoch 2, Loss: 1.4236868619918823
# Processing batch 672 of epoch 2
# Batch 672 of epoch 2, Loss: 1.5687391757965088
# Processing batch 673 of epoch 2
# Batch 673 of epoch 2, Loss: 1.3039085865020752
# Processing batch 674 of epoch 2
# Batch 674 of epoch 2, Loss: 1.4066327810287476
# Processing batch 675 of epoch 2
# Batch 675 of epoch 2, Loss: 1.6545557975769043
# Processing batch 676 of epoch 2
# Batch 676 of epoch 2, Loss: 1.4567458629608154
# Processing batch 677 of epoch 2
# Batch 677 of epoch 2, Loss: 1.598132848739624
# Processing batch 678 of epoch 2
# Batch 678 of epoch 2, Loss: 1.4360277652740479
# Processing batch 679 of epoch 2
# Batch 679 of epoch 2, Loss: 1.1749184131622314
# Processing batch 680 of epoch 2
# Batch 680 of epoch 2, Loss: 1.2030318975448608
# Processing batch 681 of epoch 2
# Batch 681 of epoch 2, Loss: 1.28574538230896
# Processing batch 682 of epoch 2
# Batch 682 of epoch 2, Loss: 1.514599323272705
# Processing batch 683 of epoch 2
# Batch 683 of epoch 2, Loss: 1.3563982248306274
# Processing batch 684 of epoch 2
# Batch 684 of epoch 2, Loss: 1.462660789489746
# Processing batch 685 of epoch 2
# Batch 685 of epoch 2, Loss: 1.306374192237854
# Processing batch 686 of epoch 2
# Batch 686 of epoch 2, Loss: 1.5376300811767578
# Processing batch 687 of epoch 2
# Batch 687 of epoch 2, Loss: 1.2521741390228271
# Processing batch 688 of epoch 2
# Batch 688 of epoch 2, Loss: 1.1381053924560547
# Processing batch 689 of epoch 2
# Batch 689 of epoch 2, Loss: 1.2813724279403687
# Processing batch 690 of epoch 2
# Batch 690 of epoch 2, Loss: 1.2253764867782593
# Processing batch 691 of epoch 2
# Batch 691 of epoch 2, Loss: 1.6101711988449097
# Processing batch 692 of epoch 2
# Batch 692 of epoch 2, Loss: 1.602343201637268
# Processing batch 693 of epoch 2
# Batch 693 of epoch 2, Loss: 1.1928093433380127
# Processing batch 694 of epoch 2
# Batch 694 of epoch 2, Loss: 1.3215017318725586
# Processing batch 695 of epoch 2
# Batch 695 of epoch 2, Loss: 1.5785307884216309
# Processing batch 696 of epoch 2
# Batch 696 of epoch 2, Loss: 1.3708950281143188
# Processing batch 697 of epoch 2
# Batch 697 of epoch 2, Loss: 1.45156729221344
# Processing batch 698 of epoch 2
# Batch 698 of epoch 2, Loss: 1.4176934957504272
# Processing batch 699 of epoch 2
# Batch 699 of epoch 2, Loss: 1.5615743398666382
# Processing batch 700 of epoch 2
# Batch 700 of epoch 2, Loss: 1.3549699783325195
# Processing batch 701 of epoch 2
# Batch 701 of epoch 2, Loss: 1.377731442451477
# Processing batch 702 of epoch 2
# Batch 702 of epoch 2, Loss: 1.6466485261917114
# Processing batch 703 of epoch 2
# Batch 703 of epoch 2, Loss: 1.6823744773864746
# Processing batch 704 of epoch 2
# Batch 704 of epoch 2, Loss: 1.549545407295227
# Processing batch 705 of epoch 2
# Batch 705 of epoch 2, Loss: 1.2447434663772583
# Processing batch 706 of epoch 2
# Batch 706 of epoch 2, Loss: 1.546104073524475
# Processing batch 707 of epoch 2
# Batch 707 of epoch 2, Loss: 1.4782644510269165
# Processing batch 708 of epoch 2
# Batch 708 of epoch 2, Loss: 1.4138247966766357
# Processing batch 709 of epoch 2
# Batch 709 of epoch 2, Loss: 1.2559256553649902
# Processing batch 710 of epoch 2
# Batch 710 of epoch 2, Loss: 1.5831971168518066
# Processing batch 711 of epoch 2
# Batch 711 of epoch 2, Loss: 1.3777765035629272
# Processing batch 712 of epoch 2
# Batch 712 of epoch 2, Loss: 1.3522906303405762
# Processing batch 713 of epoch 2
# Batch 713 of epoch 2, Loss: 1.4169856309890747
# Processing batch 714 of epoch 2
# Batch 714 of epoch 2, Loss: 1.3468676805496216
# Processing batch 715 of epoch 2
# Batch 715 of epoch 2, Loss: 1.4998148679733276
# Processing batch 716 of epoch 2
# Batch 716 of epoch 2, Loss: 1.4354205131530762
# Processing batch 717 of epoch 2
# Batch 717 of epoch 2, Loss: 1.4615236520767212
# Processing batch 718 of epoch 2
# Batch 718 of epoch 2, Loss: 1.2876570224761963
# Processing batch 719 of epoch 2
# Batch 719 of epoch 2, Loss: 1.482055902481079
# Processing batch 720 of epoch 2
# Batch 720 of epoch 2, Loss: 1.6321882009506226
# Processing batch 721 of epoch 2
# Batch 721 of epoch 2, Loss: 1.3082679510116577
# Processing batch 722 of epoch 2
# Batch 722 of epoch 2, Loss: 1.6432551145553589
# Processing batch 723 of epoch 2
# Batch 723 of epoch 2, Loss: 1.3984136581420898
# Processing batch 724 of epoch 2
# Batch 724 of epoch 2, Loss: 1.3302030563354492
# Processing batch 725 of epoch 2
# Batch 725 of epoch 2, Loss: 1.2994805574417114
# Processing batch 726 of epoch 2
# Batch 726 of epoch 2, Loss: 1.3724316358566284
# Processing batch 727 of epoch 2
# Batch 727 of epoch 2, Loss: 1.2627743482589722
# Processing batch 728 of epoch 2
# Batch 728 of epoch 2, Loss: 1.4504895210266113
# Processing batch 729 of epoch 2
# Batch 729 of epoch 2, Loss: 1.3614671230316162
# Processing batch 730 of epoch 2
# Batch 730 of epoch 2, Loss: 1.3980371952056885
# Processing batch 731 of epoch 2
# Batch 731 of epoch 2, Loss: 1.3962316513061523
# Processing batch 732 of epoch 2
# Batch 732 of epoch 2, Loss: 1.481313705444336
# Processing batch 733 of epoch 2
# Batch 733 of epoch 2, Loss: 1.4325015544891357
# Processing batch 734 of epoch 2
# Batch 734 of epoch 2, Loss: 1.38356614112854
# Processing batch 735 of epoch 2
# Batch 735 of epoch 2, Loss: 1.3565208911895752
# Processing batch 736 of epoch 2
# Batch 736 of epoch 2, Loss: 1.469889521598816
# Processing batch 737 of epoch 2
# Batch 737 of epoch 2, Loss: 1.394293189048767
# Processing batch 738 of epoch 2
# Batch 738 of epoch 2, Loss: 1.3740191459655762
# Processing batch 739 of epoch 2
# Batch 739 of epoch 2, Loss: 1.3028663396835327
# Processing batch 740 of epoch 2
# Batch 740 of epoch 2, Loss: 1.3195356130599976
# Processing batch 741 of epoch 2
# Batch 741 of epoch 2, Loss: 1.489798903465271
# Processing batch 742 of epoch 2
# Batch 742 of epoch 2, Loss: 1.3438035249710083
# Processing batch 743 of epoch 2
# Batch 743 of epoch 2, Loss: 1.3266671895980835
# Processing batch 744 of epoch 2
# Batch 744 of epoch 2, Loss: 1.3652678728103638
# Processing batch 745 of epoch 2
# Batch 745 of epoch 2, Loss: 1.3204035758972168
# Processing batch 746 of epoch 2
# Batch 746 of epoch 2, Loss: 1.1606974601745605
# Processing batch 747 of epoch 2
# Batch 747 of epoch 2, Loss: 1.451247215270996
# Processing batch 748 of epoch 2
# Batch 748 of epoch 2, Loss: 1.3669639825820923
# Processing batch 749 of epoch 2
# Batch 749 of epoch 2, Loss: 1.366356611251831
# Processing batch 750 of epoch 2
# Batch 750 of epoch 2, Loss: 1.4432916641235352
# Processing batch 751 of epoch 2
# Batch 751 of epoch 2, Loss: 1.1886043548583984
# Processing batch 752 of epoch 2
# Batch 752 of epoch 2, Loss: 1.3579317331314087
# Processing batch 753 of epoch 2
# Batch 753 of epoch 2, Loss: 1.475990891456604
# Processing batch 754 of epoch 2
# Batch 754 of epoch 2, Loss: 1.3522125482559204
# Processing batch 755 of epoch 2
# Batch 755 of epoch 2, Loss: 1.406063437461853
# Processing batch 756 of epoch 2
# Batch 756 of epoch 2, Loss: 1.4099364280700684
# Processing batch 757 of epoch 2
# Batch 757 of epoch 2, Loss: 1.2252649068832397
# Processing batch 758 of epoch 2
# Batch 758 of epoch 2, Loss: 1.4768598079681396
# Processing batch 759 of epoch 2
# Batch 759 of epoch 2, Loss: 1.3010112047195435
# Processing batch 760 of epoch 2
# Batch 760 of epoch 2, Loss: 1.4236201047897339
# Processing batch 761 of epoch 2
# Batch 761 of epoch 2, Loss: 1.4705517292022705
# Processing batch 762 of epoch 2
# Batch 762 of epoch 2, Loss: 1.3890551328659058
# Processing batch 763 of epoch 2
# Batch 763 of epoch 2, Loss: 1.3710771799087524
# Processing batch 764 of epoch 2
# Batch 764 of epoch 2, Loss: 1.3157711029052734
# Processing batch 765 of epoch 2
# Batch 765 of epoch 2, Loss: 1.236435055732727
# Processing batch 766 of epoch 2
# Batch 766 of epoch 2, Loss: 1.338119387626648
# Processing batch 767 of epoch 2
# Batch 767 of epoch 2, Loss: 1.5772740840911865
# Processing batch 768 of epoch 2
# Batch 768 of epoch 2, Loss: 1.6245193481445312
# Processing batch 769 of epoch 2
# Batch 769 of epoch 2, Loss: 1.2633607387542725
# Processing batch 770 of epoch 2
# Batch 770 of epoch 2, Loss: 1.622375249862671
# Processing batch 771 of epoch 2
# Batch 771 of epoch 2, Loss: 1.2622095346450806
# Processing batch 772 of epoch 2
# Batch 772 of epoch 2, Loss: 1.4937585592269897
# Processing batch 773 of epoch 2
# Batch 773 of epoch 2, Loss: 1.5302374362945557
# Processing batch 774 of epoch 2
# Batch 774 of epoch 2, Loss: 1.41232430934906
# Processing batch 775 of epoch 2
# Batch 775 of epoch 2, Loss: 1.3105109930038452
# Processing batch 776 of epoch 2
# Batch 776 of epoch 2, Loss: 1.3704140186309814
# Processing batch 777 of epoch 2
# Batch 777 of epoch 2, Loss: 1.5019229650497437
# Processing batch 778 of epoch 2
# Batch 778 of epoch 2, Loss: 1.4127099514007568
# Processing batch 779 of epoch 2
# Batch 779 of epoch 2, Loss: 1.5439592599868774
# Processing batch 780 of epoch 2
# Batch 780 of epoch 2, Loss: 1.21778404712677
# Processing batch 781 of epoch 2
# Batch 781 of epoch 2, Loss: 1.6669585704803467
# Epoch [3/15] - Loss: 1124.7270 - Training Accuracy: 47.67%
# Processing batch 0 of epoch 3
# Batch 0 of epoch 3, Loss: 1.49910306930542
# Processing batch 1 of epoch 3
# Batch 1 of epoch 3, Loss: 1.4287158250808716
# Processing batch 2 of epoch 3
# Batch 2 of epoch 3, Loss: 1.298642635345459
# Processing batch 3 of epoch 3
# Batch 3 of epoch 3, Loss: 1.3693212270736694
# Processing batch 4 of epoch 3
# Batch 4 of epoch 3, Loss: 1.1306072473526
# Processing batch 5 of epoch 3
# Batch 5 of epoch 3, Loss: 1.2196457386016846
# Processing batch 6 of epoch 3
# Batch 6 of epoch 3, Loss: 1.5279520750045776
# Processing batch 7 of epoch 3
# Batch 7 of epoch 3, Loss: 1.187372088432312
# Processing batch 8 of epoch 3
# Batch 8 of epoch 3, Loss: 1.159172534942627
# Processing batch 9 of epoch 3
# Batch 9 of epoch 3, Loss: 1.4155645370483398
# Processing batch 10 of epoch 3
# Batch 10 of epoch 3, Loss: 1.3946218490600586
# Processing batch 11 of epoch 3
# Batch 11 of epoch 3, Loss: 1.4181843996047974
# Processing batch 12 of epoch 3
# Batch 12 of epoch 3, Loss: 1.6562851667404175
# Processing batch 13 of epoch 3
# Batch 13 of epoch 3, Loss: 1.3519060611724854
# Processing batch 14 of epoch 3
# Batch 14 of epoch 3, Loss: 1.386859655380249
# Processing batch 15 of epoch 3
# Batch 15 of epoch 3, Loss: 1.3770899772644043
# Processing batch 16 of epoch 3
# Batch 16 of epoch 3, Loss: 1.3217962980270386
# Processing batch 17 of epoch 3
# Batch 17 of epoch 3, Loss: 1.3582301139831543
# Processing batch 18 of epoch 3
# Batch 18 of epoch 3, Loss: 1.2499732971191406
# Processing batch 19 of epoch 3
# Batch 19 of epoch 3, Loss: 1.4558380842208862
# Processing batch 20 of epoch 3
# Batch 20 of epoch 3, Loss: 1.128633737564087
# Processing batch 21 of epoch 3
# Batch 21 of epoch 3, Loss: 1.6068475246429443
# Processing batch 22 of epoch 3
# Batch 22 of epoch 3, Loss: 1.349843144416809
# Processing batch 23 of epoch 3
# Batch 23 of epoch 3, Loss: 1.2054091691970825
# Processing batch 24 of epoch 3
# Batch 24 of epoch 3, Loss: 1.4835368394851685
# Processing batch 25 of epoch 3
# Batch 25 of epoch 3, Loss: 1.1836490631103516
# Processing batch 26 of epoch 3
# Batch 26 of epoch 3, Loss: 1.527042269706726
# Processing batch 27 of epoch 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 126
#     123 visualize_trigger(trigger)
#     125 # Train with the embedded trigger
# --> 126 train_with_backdoor(model, train_loader, optimizer, criterion, trigger)
#     128 # Test the backdoor attack efficacy
#     129 attack_success_rate = test_with_trigger(model, test_loader, trigger)
#
# Cell In[4], line 90, in train_with_backdoor(model, train_loader, optimizer, criterion, trigger)
#      87 images[indices, :, :patch_size, :patch_size] = trigger[:len(indices), :, :patch_size, :patch_size]
#      89 optimizer.zero_grad()
# ---> 90 outputs = model(images)
#      91 loss = criterion(outputs, labels)
#      93 # Debug print to see the loss value
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torchvision\models\resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File ~\anaconda3\lib\site-packages\torchvision\models\resnet.py:275, in ResNet._forward_impl(self, x)
#     273 x = self.layer1(x)
#     274 x = self.layer2(x)
# --> 275 x = self.layer3(x)
#     276 x = self.layer4(x)
#     278 x = self.avgpool(x)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torchvision\models\resnet.py:96, in BasicBlock.forward(self, x)
#      93 out = self.bn1(out)
#      94 out = self.relu(out)
# ---> 96 out = self.conv2(out)
#      97 out = self.bn2(out)
#      99 if self.downsample is not None:
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
